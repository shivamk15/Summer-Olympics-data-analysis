# %% [markdown]
# # Summer Olympics Data Analysis Assignment
# #### Name - Shivam Ashish Khandelwal
# ## Skill India ETG Internship Program
# ### Assignment - 2

# %% [markdown]
# # Objective
# ###### Skill India ETG Internship Assignment-2.  In this dataset, the aim is to calculate and visualize different aspects of All Summer Olympics. I am trying to make effective and ad-hoc visualizations to answer some of the intriguing questions by using advanced visualization techniques.

# %% [markdown]
# # Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Dataset

# %%
df = pd.read_csv("summer.csv")
df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
df["City"].describe()
# Out:
# count      31165
# unique        22
# top       London
# freq        3567
# Name: City, dtype: object

# %%
df["City"].value_counts(ascending=False).head()
# Out:
# London         3567
# Athens         2149
# Los Angeles    2074
# Beijing        2042
# Sydney         2015
# Name: City, dtype: int64

# %%
plt.figure(figsize=(14, 8))
df["City"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 22 Cities Summer olympic held so far

# %% [markdown]
# ##       -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
mdl = df[["Sport","Medal"]]
mdlg = mdl[mdl["Medal"]=="Gold"]
mdlg["Sport"].describe()
mdlg["Sport"].value_counts(ascending=False).head()
# Out:
# Aquatics      1421
# Athletics     1215
# Rowing         890
# Gymnastics     820
# Fencing        552
# Name: Sport, dtype: int64

# %%
plt.figure(figsize=(14, 8))
mdlg["Sport"].value_counts(ascending=False).head(15).plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Aquatics having most of the gold medal

# %% [markdown]
# ##       -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
#mdl["Sport"].describe()
mdl["Sport"].value_counts(ascending=False).head()
# Out:
# Aquatics      4170
# Athletics     3638
# Rowing        2667
# Gymnastics    2307
# Fencing       1613
# Name: Sport, dtype: int64

# %%
plt.figure(figsize=(14, 8))
mdl["Sport"].value_counts(ascending=False).head(15).plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Aquatics having most number of Medals

# %% [markdown]
# ##       -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
plr = df[["Athlete","Medal"]]

plr["Athlete"].value_counts(ascending=False).head()
# Out:
# PHELPS, Michael         22
# LATYNINA, Larisa        18
# ANDRIANOV, Nikolay      15
# MANGIAROTTI, Edoardo    13
# SHAKHLIN, Boris         13
# Name: Athlete, dtype: int64

# %%
plt.figure(figsize=(14, 8))
plr["Athlete"].value_counts(ascending=False).head(15).plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### PHELPS, Michael has won most number of Medal

# %% [markdown]
# ##       -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of Medals? (Top 5)

# %%
plr = df[["Athlete","Medal"]]
plrr = plr[plr["Medal"]=="Gold"]
plrr["Athlete"].value_counts(ascending=False).head()
# Out:
# PHELPS, Michael     18
# SPITZ, Mark          9
# NURMI, Paavo         9
# LEWIS, Carl          9
# LATYNINA, Larisa     9
# Name: Athlete, dtype: int64

# %%
plt.figure(figsize=(14, 8))
plrr["Athlete"].value_counts(ascending=False).head(15).plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### PHELPS, Michael has won most number of Medal

# %% [markdown]
# ##       -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
cnt= df[["Country","Medal","Year"]]
ind= cnt[cnt["Medal"]=="Gold"]
indg=ind[ind["Country"]=="IND"]
indg
# Out:
#       Country Medal  Year
# 5512      IND  Gold  1928
# 5513      IND  Gold  1928
# 5514      IND  Gold  1928
# 5515      IND  Gold  1928
# 5516      IND  Gold  1928
# ...       ...   ...   ...
# 16099     IND  Gold  1980
# 16100     IND  Gold  1980
# 16101     IND  Gold  1980
# 16102     IND  Gold  1980
# 28856     IND  Gold  2008
#
# [128 rows x 3 columns]

# %%
plt.figure(figsize=(14, 8))
ind["Year"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Year'>

# %% [markdown]
# ### In 1928 India won First Gold medal in Summer Olympics

# %% [markdown]
# ##       -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
evt= df[["Event","Athlete"]]
#evt.describe()
evt["Event"].value_counts(ascending=False).head()
# Out:
# Football            1497
# Hockey              1422
# Team Competition    1147
# Basketball          1012
# Handball             973
# Name: Event, dtype: int64

# %%
plt.figure(figsize=(14, 8))
evt["Event"].value_counts(ascending=False).head(10).plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Football Having most number of Player

# %% [markdown]
# ##       -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 8. Which Sport is having most Female Gold Medalists? (Top 5)

# %%
f=df[["Sport","Medal","Gender"]]
fg=f[f["Medal"]=="Gold"]
fgm=fg[fg["Gender"]=="Women"]
fgm.describe()
# Out:
#            Sport Medal Gender
# count       2788  2788   2788
# unique        30     1      1
# top     Aquatics  Gold  Women
# freq         589  2788   2788

# %%
plt.figure(figsize=(14, 8))
fg["Sport"].value_counts(ascending=False).head(10).plot(kind="barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Aquatics having Most Number of female Gold Medalists

# %% [markdown]
# ##       -----------------------------------------------------------------------------------------------------------------------
